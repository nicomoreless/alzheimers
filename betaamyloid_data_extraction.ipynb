# %%
import pandas as pd 
from chembl_webresource_client.new_client import new_client
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %%
# !pip install rdkit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.8/24.8 MB 12.0 MB/s eta 0:00:0000:0100:01
# ...

# %%
#target search for beta-amyloid

target = new_client.target
target_query = target.search('Beta amyloid')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                        cross_references           organism  \
# 0     [{'xref_id': 'P05067', 'xref_name': None, 'xre...       Homo sapiens
# 1                                                    []  Rattus norvegicus
# 2                                                    []       Mus musculus
# 3                                                    []       Homo sapiens
# 4     [{'xref_id': 'P37840', 'xref_name': None, 'xre...       Homo sapiens
# ...                                                 ...                ...
# 1277                                                 []           Bacteria
# 1278                                                 []       Homo sapiens
# 1279                                                 []       Homo sapiens
# 1280                                                 []       Homo sapiens
# 1281                                                 []           Bacteria
#
# ...

# %%
targets = targets[targets['target_type'] == 'SINGLE PROTEIN']
targets = targets[targets['organism'] == 'Homo sapiens']

# %%
targets
# Out:
#                                        cross_references      organism  \
# 0     [{'xref_id': 'P05067', 'xref_name': None, 'xre...  Homo sapiens
# 3                                                    []  Homo sapiens
# 4     [{'xref_id': 'P37840', 'xref_name': None, 'xre...  Homo sapiens
# 5                                                    []  Homo sapiens
# 6     [{'xref_id': 'Q92542', 'xref_name': None, 'xre...  Homo sapiens
# ...                                                 ...           ...
# 1259                                                 []  Homo sapiens
# 1260                                                 []  Homo sapiens
# 1261                                                 []  Homo sapiens
# 1263                                                 []  Homo sapiens
# 1264                                                 []  Homo sapiens
#
#                                           pref_name  score  \
# 0                           Beta amyloid A4 protein   20.0
# ...

# %%
#Select and retrieve bioactivity data for Beta amyloid A4 protein
selected_target = targets.target_chembl_id[0]

selected_target
# Out:
# 'CHEMBL2487'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type='IC50')

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#      activity_comment  activity_id  \
# 0                None       357577
# 1                None       357580
# 2                None       358965
# 3                None       368887
# 4                None       375954
# ...               ...          ...
# 1492             None     24511197
# 1493             None     24511198
# 1494             None     24511199
# 1495             None     24511202
# 1496             None     24511204
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL678443
# 1                                                    []    CHEMBL678443
# 2                                                    []    CHEMBL678443
# 3                                                    []    CHEMBL678443
# 4                                                    []    CHEMBL678443
# ...                                                 ...             ...
# ...

# %%
df.to_csv('betaamyloid_01_bioactivity_data_raw.csv')

# %% [markdown]
# Handling missing data

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /var/folders/vn/0pllmk4d2q7dl5gq08l8hdxc0000gn/T/ipykernel_10429/3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#      activity_comment  activity_id  \
# 0                None       357577
# 1                None       357580
# 2                None       358965
# 3                None       368887
# 4                None       375954
# ...               ...          ...
# 1492             None     24511197
# 1493             None     24511198
# 1494             None     24511199
# 1495             None     24511202
# 1496             None     24511204
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL678443
# 1                                                    []    CHEMBL678443
# 2                                                    []    CHEMBL678443
# ...

# %%
#length
len(df2.canonical_smiles.unique())
# Out:
# 1125

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      activity_comment  activity_id  \
# 0                None       357577
# 1                None       357580
# 2                None       358965
# 3                None       368887
# 4                None       375954
# ...               ...          ...
# 1489             None     24511194
# 1490             None     24511195
# 1491             None     24511196
# 1492             None     24511197
# 1493             None     24511198
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL678443
# 1                                                    []    CHEMBL678443
# 2                                                    []    CHEMBL678443
# 3                                                    []    CHEMBL678443
# 4                                                    []    CHEMBL678443
# ...                                                 ...             ...
# ...

# %%
#DATA pre-processing og the bioactivity data
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1          CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2          CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3           CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4           CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...                 ...                                                ...
# 1489      CHEMBL5075177  COc1cnc(C(=O)Nc2ccc(F)c([C@]3(C)CO[C@@](C)(C(F...
# 1490      CHEMBL5086270  Cc1cc(OC(F)F)cnc1C(=O)Nc1ccc(F)c([C@]2(C)CO[C@...
# 1491      CHEMBL5074449  C[C@@]1(c2cc(NC(=O)c3ncc(OC(F)F)cc3Cl)ccc2F)CO...
# 1492      CHEMBL5085959  C[C@@]1(c2cc(NC(=O)c3ncc(Cl)cc3Cl)ccc2F)CO[C@@...
# 1493      CHEMBL3653401  C[C@@]1(c2cc(NC(=O)c3ccc(Br)cn3)ccc2F)CO[C@@](...
#
#      standard_value
# 0            5000.0
# 1            2700.0
# ...

# %%
df3.to_csv('betaamyloid_02_bioactivity_data_preprocessed.csv', index=False)

# %%
#Labeling compounds as either being active, inactive or intermediate

# %%
df4 = pd.read_csv('betaamyloid_02_bioactivity_data_preprocessed.csv')

# %%
bioactivy_threshold = []
for i in df4.standard_value:
    if float(i) >= 10000:
        bioactivy_threshold.append('inactive')
    elif float(i) <= 1000:
        bioactivy_threshold.append('active')
    else:
        bioactivy_threshold.append('intermediate')

# %%
bioactivity_class = pd.Series(bioactivy_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class],axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1          CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2          CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3           CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4           CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...                 ...                                                ...
# 1120      CHEMBL5075177  COc1cnc(C(=O)Nc2ccc(F)c([C@]3(C)CO[C@@](C)(C(F...
# 1121      CHEMBL5086270  Cc1cc(OC(F)F)cnc1C(=O)Nc1ccc(F)c([C@]2(C)CO[C@...
# 1122      CHEMBL5074449  C[C@@]1(c2cc(NC(=O)c3ncc(OC(F)F)cc3Cl)ccc2F)CO...
# 1123      CHEMBL5085959  C[C@@]1(c2cc(NC(=O)c3ncc(Cl)cc3Cl)ccc2F)CO[C@@...
# 1124      CHEMBL3653401  C[C@@]1(c2cc(NC(=O)c3ccc(Br)cn3)ccc2F)CO[C@@](...
#
#       standard_value         class
# ...

# %%
df5.to_csv('betaamyloid_03_bioactivity_data_curated.csv', index=False)

# %% [markdown]
# Lipinsky rules:
# Molecular weight < 500 daltons
# octanol water partition coefficient (logP) < 5
# Hydrogen bond donors < 5
# Hydrogen bond acceptors < 5

# %%
def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem) 
        moldata.append(mol)
       
    baseData= np.arange(1,1)
    i=0  
    for mol in moldata:        
       
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])   
    
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1      
    
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return descriptors

# %%
df_lipinski = lipinski(df_clean_smiles.canonical_smiles)
